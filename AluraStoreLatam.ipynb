# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px


url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

display(tienda.head())

df_tienda_total = pd.concat([tienda, tienda2, tienda3, tienda4])
#tienda_completa = pd.concat([tienda, tienda2, tienda3, tienda4])
print("---------------------------------------------------------------------Head Tienda Completa------------------------------------------------------------------------------------------------------")

df_tienda_total.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# 1  Tarjeta de crédito                   4   6.25184 -75.56359
# 2  Tarjeta de crédito                   1  10.39972 -75.51444
# 3               Nequi                   1   3.43722 -76.52250
# 4               Nequi                   1   6.25184 -75.56359
# ---------------------------------------------------------------------Head Tienda Completa------------------------------------------------------------------------------------------------------
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# 1  Tarjeta de crédito                   4   6.25184 -75.56359
# 2  Tarjeta de crédito                   1  10.39972 -75.51444
# 3               Nequi                   1   3.43722 -76.52250
# 4               Nequi                   1   6.25184 -75.56359

# %% [markdown]
# #1. Análisis de facturación

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px
import matplotlib.ticker as mtick

df_tienda_total = pd.concat([tienda, tienda2, tienda3, tienda4])

# Calculando el total para cada tienda
total_tienda1 = tienda['Precio'].sum()
total_tienda2 = tienda2['Precio'].sum()
total_tienda3 = tienda3['Precio'].sum()
total_tienda4 = tienda4['Precio'].sum()


# Calculando el total de las tiendas
total_sum = total_tienda1 + total_tienda2 + total_tienda3 + total_tienda4 #1era Forma
total_tienda_completa= df_tienda_total['Precio'].sum() # 2da Forma

# Imrpimiendo el total de facturación de cada tienda
print("Facturación Total Tienda 1:", total_tienda1)
print("Facturación Total Tienda 2:", total_tienda2)
print("Facturación Total Tienda 3:", total_tienda3)
print("Facturación Total Tienda 4:", total_tienda4)

# Imrpimiendo la suma de la facturación total de todas las tiendas
print("Facturación Total de Todas las tiendas:", total_sum)
print("----------------------------------------------------------Otra forma------------------------------------------------------------------------------------")
print("Facturación Total de Todas las tiendas:", total_tienda_completa)

tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']
total_facturacion = [total_tienda1, total_tienda2, total_tienda3, total_tienda4]
colores = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728']
plt.plot(tiendas, total_facturacion, marker='o', linestyle='-', color='blue')
plt.xlabel('Tiendas')
plt.ylabel('Total de Facturación')
plt.title('Total de Facturación de Cada Tienda')

# Aplicar formato de dinero con signo $
formatter = mtick.StrMethodFormatter('${x:,.0f}')
plt.gca().yaxis.set_major_formatter(formatter)

plt.grid(True)
plt.show()
# Out:
# Facturación Total Tienda 1: 1150880400.0
# Facturación Total Tienda 2: 1116343500.0
# Facturación Total Tienda 3: 1098019600.0
# Facturación Total Tienda 4: 1038375700.0
# Facturación Total de Todas las tiendas: 4403619200.0
# ----------------------------------------------------------Otra forma------------------------------------------------------------------------------------
# Facturación Total de Todas las tiendas: 4403619200.0

# %%
# Creando DataFrame para los gráficos
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as mtick
import plotly.express as px

# Se crea un DataFrame para el Plotting
df_facturacion = pd.DataFrame({'Tienda': tiendas, 'Total de Facturación': total_facturacion})


fig = px.line(
    df_facturacion,
    x='Tienda',
    y='Total de Facturación',
    labels={'Tienda': 'Tiendas', 'Total de Facturación': 'Total de Facturación'},
    title='Total de Facturación de Cada Tienda ',
    markers=True
)

# Se actualiza el rango del eje Y y su formato
fig.update_layout(
    yaxis=dict(
        range=[0, max(df_facturacion['Total de Facturación']) * 1.10], # Set the y-axis range
        tickprefix='$',
        tickformat=','
    )
)


fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="cbc8039e-287d-4dfd-93fe-dd8d60812748" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cbc8039e-287d-4dfd-93fe-dd8d60812748")) {                    Plotly.newPlot(                        "cbc8039e-287d-4dfd-93fe-dd8d60812748",                        [{"hovertemplate":"Tiendas=%{x}\u003cbr\u003eTotal de Facturación=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":["Tienda 1","Tienda 2","Tienda 3","Tienda 4"],"xaxis":"x","y":[1150880400.0,1116343500.0,1098019600.0,1038375700.0],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","m ...

# %%
# Gráficos con plotly

fig = px.bar(
    df_facturacion,
    x='Tienda',
    y='Total de Facturación',
    labels={'Tienda': 'Tiendas', 'Total de Facturación': 'Total de Facturación'},
    title='Total de Facturación de Cada Tienda ',
)

fig.update_layout(yaxis_tickprefix='$', yaxis_tickformat=',')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2a8c6d9c-f57f-44dc-abef-4d2cbc279a71" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2a8c6d9c-f57f-44dc-abef-4d2cbc279a71")) {                    Plotly.newPlot(                        "2a8c6d9c-f57f-44dc-abef-4d2cbc279a71",                        [{"alignmentgroup":"True","hovertemplate":"Tiendas=%{x}\u003cbr\u003eTotal de Facturación=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Tienda 1","Tienda 2","Tienda 3","Tienda 4"],"xaxis":"x","y":[1150880400.0,1116343500.0,1098019600.0,1038375700.0],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type ...

# %% [markdown]
# # 2. Ventas por categoría

# %%
#Utilizando Dataframe de Librería Pandas

#Ventas Por Categoría

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px
import numpy as np


ventas_por_producto = df_tienda_total['Categoría del Producto'].value_counts()
venta_por_producto_reseteada = ventas_por_producto.reset_index()
ventas_productos_final = venta_por_producto_reseteada.rename(columns={'count': 'Ventas'})
print("-----------------TIENDA TOTAL---------------------------------------")
print(ventas_productos_final)

print("-----------------TIENDA 1---------------------------------------")


ventas_por_producto1 = tienda['Categoría del Producto'].value_counts()
venta_por_producto_reseteada1 = ventas_por_producto1.reset_index()

ventas_productos_final1 = venta_por_producto_reseteada1.rename(columns={'count': 'Ventas'})
print(ventas_productos_final1)

print("-----------------TIENDA 2---------------------------------------")
ventas_por_producto2 = tienda2['Categoría del Producto'].value_counts()
venta_por_producto_reseteada2 = ventas_por_producto2.reset_index()

ventas_productos_final2 = venta_por_producto_reseteada2.rename(columns={'count': 'Ventas'})
print(ventas_productos_final2)

print("-----------------TIENDA 3---------------------------------------")
ventas_por_producto3 = tienda3['Categoría del Producto'].value_counts()
venta_por_producto_reseteada3 = ventas_por_producto3.reset_index()

ventas_productos_final3 = venta_por_producto_reseteada3.rename(columns={'count': 'Ventas'})
print(ventas_productos_final3)

print("-----------------TIENDA 4---------------------------------------")
ventas_por_producto4 = tienda4['Categoría del Producto'].value_counts()
venta_por_producto_reseteada4 = ventas_por_producto4.reset_index()

ventas_productos_final4 = venta_por_producto_reseteada4.rename(columns={'count': 'Ventas'})
print(ventas_productos_final4)


# Asegurarse de que todos los DataFrames tengan nombres consistentes
ventas_productos_final = ventas_productos_final.rename(columns={'index': 'Categoría del Producto'})
ventas_productos_final1 = ventas_productos_final1.rename(columns={'index': 'Categoría del Producto'})
ventas_productos_final2 = ventas_productos_final2.rename(columns={'index': 'Categoría del Producto'})
ventas_productos_final3 = ventas_productos_final3.rename(columns={'index': 'Categoría del Producto'})
ventas_productos_final4 = ventas_productos_final4.rename(columns={'index': 'Categoría del Producto'})

# Unir los datos por categoría
df_unificado = ventas_productos_final[['Categoría del Producto', 'Ventas']].rename(columns={'Ventas': 'Tienda Total'})
df_unificado = df_unificado.merge(ventas_productos_final1, on='Categoría del Producto', how='left').rename(columns={'Ventas': 'Tienda 1'})
df_unificado = df_unificado.merge(ventas_productos_final2, on='Categoría del Producto', how='left').rename(columns={'Ventas': 'Tienda 2'})
df_unificado = df_unificado.merge(ventas_productos_final3, on='Categoría del Producto', how='left').rename(columns={'Ventas': 'Tienda 3'})
df_unificado = df_unificado.merge(ventas_productos_final4, on='Categoría del Producto', how='left').rename(columns={'Ventas': 'Tienda 4'})

print("------ DataFrame Unificado ------")
print(df_unificado)
# Out:
# -----------------TIENDA TOTAL---------------------------------------
#     Categoría del Producto  Ventas
# 0                  Muebles    1886
# 1             Electrónicos    1772
# 2                 Juguetes    1290
# 3        Electrodomésticos    1149
# 4     Deportes y diversión    1113
# 5   Instrumentos musicales     753
# 6                   Libros     742
# 7  Artículos para el hogar     730
# -----------------TIENDA 1---------------------------------------
#     Categoría del Producto  Ventas
# 0                  Muebles     465
# 1             Electrónicos     448
# 2                 Juguetes     324
# 3        Electrodomésticos     312
# 4     Deportes y diversión     284
# 5   Instrumentos musicales     182
# 6                   Libros     173
# 7  Artículos para el hogar     171
# -----------------TIENDA 2---------------------------------------
#     Categoría del Producto  Ventas
# 0                  Muebles     442
# 1             Electrónicos     422
# 2                 Juguetes     313
# 3        Electrodomésticos     305
# 4     Deportes y diversión     275
# 5   Instrumentos musicales     224
# 6                   Libros     197
# 7  Artículos para el hogar     181
# -----------------TIENDA 3---------------------------------------
#     Categoría del Producto  Ventas
# 0                  Muebles     499
# 1             Electrónicos     451
# 2                 Juguetes     315
# 3        Electrodomésticos     278
# 4     Deportes y diversión     277
# 5                   Libros     185
# 6   Instrumentos musicales     177
# 7  Artículos para el hogar     177
# -----------------TIENDA 4---------------------------------------
#     Categoría del Producto  Ventas
# 0                  Muebles     480
# 1             Electrónicos     451
# 2                 Juguetes     338
# 3     Deportes y diversión     277
# 4        Electrodomésticos     254
# 5  Artículos para el hogar     201
# 6                   Libros     187
# 7   Instrumentos musicales     170
# ------ DataFrame Unificado ------
#     Categoría del Producto  Tienda Total  Tienda 1  Tienda 2  Tienda 3  \
# 0                  Muebles          1886       465       442       499
# 1             Electrónicos          1772       448       422       451
# 2                 Juguetes          1290       324       313       315
# 3        Electrodomésticos          1149       312       305       278
# 4     Deportes y diversión          1113       284       275       277
# 5   Instrumentos musicales           753       182       224       177
# 6                   Libros           742       173       197       185
# 7  Artículos para el hogar           730       171       181       177
#
#    Tienda 4
# 0       480
# 1       451
# 2       338
# 3       254
# 4       277
# 5       170
# 6       187
# 7       201

# %%
# Datos para graficar
categorias = df_unificado['Categoría del Producto']
ancho_barra = 0.15
x = np.arange(len(categorias))

plt.figure(figsize=(12,6))

plt.bar(x - 2*ancho_barra, df_unificado['Tienda 1'], width=ancho_barra, label='Tienda 1')
plt.bar(x - ancho_barra, df_unificado['Tienda 2'], width=ancho_barra, label='Tienda 2')
plt.bar(x, df_unificado['Tienda 3'], width=ancho_barra, label='Tienda 3')
plt.bar(x + ancho_barra, df_unificado['Tienda 4'], width=ancho_barra, label='Tienda 4')
plt.bar(x + 2*ancho_barra, df_unificado['Tienda Total'], width=ancho_barra, color='black', label='Tienda Total', alpha=0.7)

# Personalización
plt.xticks(x, categorias, rotation=45)
plt.ylabel('Ventas')
plt.title('Ventas por Categoría de Producto - Comparación entre Tiendas')
plt.legend()
plt.tight_layout()
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()


#Grafícos

# Datos para gráfico
categorias = df_unificado['Categoría del Producto']
ancho_barra = 0.2
x = np.arange(len(categorias))

# Crear figura
plt.figure(figsize=(12,6))

# Barras para cada tienda (sin incluir la tienda total)
plt.bar(x - 1.5*ancho_barra, df_unificado['Tienda 1'], width=ancho_barra, label='Tienda 1')
plt.bar(x - 0.5*ancho_barra, df_unificado['Tienda 2'], width=ancho_barra, label='Tienda 2')
plt.bar(x + 0.5*ancho_barra, df_unificado['Tienda 3'], width=ancho_barra, label='Tienda 3')
plt.bar(x + 1.5*ancho_barra, df_unificado['Tienda 4'], width=ancho_barra, label='Tienda 4')

# Personalización
plt.xticks(x, categorias, rotation=45)
plt.ylabel('Ventas')
plt.title('Ventas por Categoría - Tiendas 1 a 4')
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# Diccionario de tiendas y sus datos
tiendas = {
    'Tienda 1': df_unificado[['Categoría del Producto', 'Tienda 1']],
    'Tienda 2': df_unificado[['Categoría del Producto', 'Tienda 2']],
    'Tienda 3': df_unificado[['Categoría del Producto', 'Tienda 3']],
    'Tienda 4': df_unificado[['Categoría del Producto', 'Tienda 4']],
}

# Generar un gráfico por tienda con etiquetas en las barras
for nombre_tienda, datos in tiendas.items():
    plt.figure(figsize=(10,5))
    barras = plt.bar(datos['Categoría del Producto'], datos[nombre_tienda], color='skyblue')
    plt.xticks(rotation=45)
    plt.ylabel('Ventas')
    plt.title(f'Ventas por Categoría - {nombre_tienda}')
    plt.grid(axis='y', linestyle='--', alpha=0.3)

    # Agregar etiquetas a cada barra
    for barra in barras:
        altura = barra.get_height()
        plt.text(
            barra.get_x() + barra.get_width()/2,
            altura + 1,
            f'{int(altura)}',
            ha='center',
            va='bottom',
            fontsize=9,
            fontweight='bold'
        )

    plt.tight_layout()
    plt.show()

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
calificaciones_promedio = []

for tienda_df, nombre in zip([tienda, tienda2, tienda3, tienda4], ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']):
    calificacion_promedio = tienda_df['Calificación'].mean()
    calificaciones_promedio.append({'Tienda': nombre, 'Calificacion Promedio': calificacion_promedio})

#Crear Dataframe con Resultados
df_calificaciones_promedio = pd.DataFrame(calificaciones_promedio).sort_values(by='Tienda')
print(df_calificaciones_promedio)

# Promedio Total
promedio_total = df_calificaciones_promedio['Calificacion Promedio'].mean()
print(f'El promedio de calificación de los clientes de toda la Tienda considerando todas las categorías es: {promedio_total:.2f}')
# Out:
#      Tienda  Calificacion Promedio
# 0  Tienda 1               3.976685
# 1  Tienda 2               4.037304
# 2  Tienda 3               4.048326
# 3  Tienda 4               3.995759
# El promedio de calificación de los clientes de toda la Tienda considerando todas las categorías es: 4.01

# %%
# Graficando Calificación Promedio de la tienda

fig = px.line(
    df_calificaciones_promedio,
    x='Tienda',
    y='Calificacion Promedio',
    labels={'Tienda': 'Store', 'Calificacion Promedio': 'Calificacion Promedio'},
    title='Las Tiendas y su Calificación Promedio',
    markers=True
)

fig.update_layout(
    yaxis=dict(
        range=[3.97, 4.05],
        tickformat=".3f"
    ),
    title_x=0.5
)

fig.update_traces(text=df_calificaciones_promedio['Calificacion Promedio'].round(3), textposition="top center")

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="68bec1df-9475-4ceb-913c-c408e2cc8011" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("68bec1df-9475-4ceb-913c-c408e2cc8011")) {                    Plotly.newPlot(                        "68bec1df-9475-4ceb-913c-c408e2cc8011",                        [{"hovertemplate":"Store=%{x}\u003cbr\u003eCalificacion Promedio=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":["Tienda 1","Tienda 2","Tienda 3","Tienda 4"],"xaxis":"x","y":[3.976685036032217,4.037303942348453,4.048325561678677,3.9957591178965224],"yaxis":"y","type":"scatter","text":[3.977,4.037,4.048,3.996],"textposition":"top center"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay ...

# %%
#Calificación por Categoría

#Tienda total

df = pd.DataFrame(df_tienda_total, columns = ['Categoría del Producto', 'Calificación'])
print("--------------Se Crea DataFrame de la Tienda Total------------------------------------------")
print(df)

Categoría_promedio = df.groupby('Categoría del Producto')['Calificación'].mean()
print("------------Calificación Promedio de todos los productos de la Tienda por Categoría--------------------------------------------")
print(Categoría_promedio)
Categoría_Reseteada_df = Categoría_promedio.reset_index()
Categoría_Promedio_Tiendas = Categoría_Reseteada_df.rename(columns={'Calificación': 'Calificación Promedio'})
print("------------Calificación Promedio de toda la Tienda por Categoría RESETEADA--------------------------------------------")
print(Categoría_Reseteada_df)
print("------------Calificación Promedio de toda la Tienda por Categoría COLUMNA RENOMBRADA--------------------------------------------")
print(Categoría_Promedio_Tiendas)
print("----------------Categorías Populares de toda la Tienda------------------")
Categorías_Populares_Tiendas = Categoría_Promedio_Tiendas[Categoría_Promedio_Tiendas['Calificación Promedio'] > 4.03]
print(Categorías_Populares_Tiendas)
print("---------------Promedio de Calificación de los Clientes en toda la Tienda-----------------------------------------")
Promedio_general = Categoría_Promedio_Tiendas['Calificación Promedio'].mean()
print(f'El promedio de calificación de los clientes de toda la Tienda considerando todas las categorías es: {Promedio_general:.2f}')


fig = px.pie(
    Categorías_Populares_Tiendas,
    values='Calificación Promedio',
    names='Categoría del Producto',
    title='Calificación Categorias más Populares de la Tienda Total',
)

fig.update_traces(textposition='inside', textinfo='value')
fig.show()
# Out:
# --------------Se Crea DataFrame de la Tienda Total------------------------------------------
#        Categoría del Producto  Calificación
# 0                Electrónicos             4
# 1                     Muebles             1
# 2                    Juguetes             1
# 3           Electrodomésticos             4
# 4                     Muebles             5
# ...                       ...           ...
# 2353                  Muebles             5
# 2354                  Muebles             5
# 2355     Deportes y diversión             5
# 2356  Artículos para el hogar             5
# 2357     Deportes y diversión             5
#
# [9435 rows x 2 columns]
# ------------Calificación Promedio de todos los productos de la Tienda por Categoría--------------------------------------------
# Categoría del Producto
# Artículos para el hogar    3.979452
# Deportes y diversión       3.988320
# Electrodomésticos          4.014795
# Electrónicos               3.992664
# Instrumentos musicales     4.003984
# Juguetes                   4.070543
# Libros                     4.004043
# Muebles                    4.033934
# Name: Calificación, dtype: float64
# ------------Calificación Promedio de toda la Tienda por Categoría RESETEADA--------------------------------------------
#     Categoría del Producto  Calificación
# 0  Artículos para el hogar      3.979452
# 1     Deportes y diversión      3.988320
# 2        Electrodomésticos      4.014795
# 3             Electrónicos      3.992664
# 4   Instrumentos musicales      4.003984
# 5                 Juguetes      4.070543
# 6                   Libros      4.004043
# 7                  Muebles      4.033934
# ------------Calificación Promedio de toda la Tienda por Categoría COLUMNA RENOMBRADA--------------------------------------------
#     Categoría del Producto  Calificación Promedio
# 0  Artículos para el hogar               3.979452
# 1     Deportes y diversión               3.988320
# 2        Electrodomésticos               4.014795
# 3             Electrónicos               3.992664
# 4   Instrumentos musicales               4.003984
# 5                 Juguetes               4.070543
# 6                   Libros               4.004043
# 7                  Muebles               4.033934
# ----------------Categorías Populares de toda la Tienda------------------
#   Categoría del Producto  Calificación Promedio
# 5               Juguetes               4.070543
# 7                Muebles               4.033934
# ---------------Promedio de Calificación de los Clientes en toda la Tienda-----------------------------------------
# El promedio de calificación de los clientes de toda la Tienda considerando todas las categorías es: 4.01
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5f9c44d8-a5e4-43c2-97d1-bf0e5a584c1d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5f9c44d8-a5e4-43c2-97d1-bf0e5a584c1d")) {                    Plotly.newPlot(                        "5f9c44d8-a5e4-43c2-97d1-bf0e5a584c1d",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Categoría del Producto=%{label}\u003cbr\u003eCalificación Promedio=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Juguetes","Muebles"],"legendgroup":"","name":"","showlegend":true,"values":[4.0705426356589145,4.033934252386002],"type":"pie","textinfo":"value","textposition":"inside"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpol ...

# %%
#Tienda1
df1 = pd.DataFrame(tienda, columns = ['Categoría del Producto', 'Calificación'])
print("--------------Se Crea DataFrame de la Tienda 1------------------------------------------")
print(df1)


Categoría_promedio1 = df1.groupby('Categoría del Producto')['Calificación'].mean()
print("------------Calificación Promedio Tienda 1--------------------------------------------")
print(Categoría_promedio1)
Categoría_Reseteada_df1 = Categoría_promedio1.reset_index()
Categoría_Promedio1 = Categoría_Reseteada_df1.rename(columns={'Calificación': 'Calificación Promedio'})
print("------------Calificación Promedio Tienda 1 RESETEADA--------------------------------------------")
print(Categoría_Reseteada_df1)
print("------------Calificación Promedio Tienda 1 COLUMNA RENOMBRADA--------------------------------------------")
print(Categoría_Promedio1)
print("----------------Categorías Populares de la Tienda 1------------------")
Categorías_populares1 = Categoría_Promedio1[Categoría_Promedio1['Calificación Promedio'] > 4.03]
print(Categorías_populares1)
print("---------------Promedio de Calificación de los Clientes de la Tienda 1-----------------------------------------")
Promedio_general1 = Categoría_Promedio1['Calificación Promedio'].mean()
print(f'El promedio de calificación de los clientes de la Tienda 1 considerando todas las categorías es: {Promedio_general1:.2f}')

fig = px.pie(
    Categorías_populares1,
    values='Calificación Promedio',
    names='Categoría del Producto',
    title='Calificación Categorias Populares de la Tienda 1',
)

fig.update_traces(textposition='inside', textinfo='value')
fig.show()
# Out:
# --------------Se Crea DataFrame de la Tienda 1------------------------------------------
#      Categoría del Producto  Calificación
# 0              Electrónicos             4
# 1                   Muebles             1
# 2                  Juguetes             1
# 3         Electrodomésticos             4
# 4                   Muebles             5
# ...                     ...           ...
# 2354           Electrónicos             1
# 2355           Electrónicos             5
# 2356               Juguetes             5
# 2357                Muebles             1
# 2358           Electrónicos             4
#
# [2359 rows x 2 columns]
# ------------Calificación Promedio Tienda 1--------------------------------------------
# Categoría del Producto
# Artículos para el hogar    3.748538
# Deportes y diversión       3.897887
# Electrodomésticos          4.032051
# Electrónicos               4.004464
# Instrumentos musicales     4.049451
# Juguetes                   4.077160
# Libros                     3.976879
# Muebles                    3.946237
# Name: Calificación, dtype: float64
# ------------Calificación Promedio Tienda 1 RESETEADA--------------------------------------------
#     Categoría del Producto  Calificación
# 0  Artículos para el hogar      3.748538
# 1     Deportes y diversión      3.897887
# 2        Electrodomésticos      4.032051
# 3             Electrónicos      4.004464
# 4   Instrumentos musicales      4.049451
# 5                 Juguetes      4.077160
# 6                   Libros      3.976879
# 7                  Muebles      3.946237
# ------------Calificación Promedio Tienda 1 COLUMNA RENOMBRADA--------------------------------------------
#     Categoría del Producto  Calificación Promedio
# 0  Artículos para el hogar               3.748538
# 1     Deportes y diversión               3.897887
# 2        Electrodomésticos               4.032051
# 3             Electrónicos               4.004464
# 4   Instrumentos musicales               4.049451
# 5                 Juguetes               4.077160
# 6                   Libros               3.976879
# 7                  Muebles               3.946237
# ----------------Categorías Populares de la Tienda 1------------------
#    Categoría del Producto  Calificación Promedio
# 2       Electrodomésticos               4.032051
# 4  Instrumentos musicales               4.049451
# 5                Juguetes               4.077160
# ---------------Promedio de Calificación de los Clientes de la Tienda 1-----------------------------------------
# El promedio de calificación de los clientes de la Tienda 1 considerando todas las categorías es: 3.97
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c919944c-3208-4b44-adee-2c51c191c9c1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c919944c-3208-4b44-adee-2c51c191c9c1")) {                    Plotly.newPlot(                        "c919944c-3208-4b44-adee-2c51c191c9c1",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Categoría del Producto=%{label}\u003cbr\u003eCalificación Promedio=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Electrodomésticos","Instrumentos musicales","Juguetes"],"legendgroup":"","name":"","showlegend":true,"values":[4.032051282051282,4.049450549450549,4.077160493827161],"type":"pie","textinfo":"value","textposition":"inside"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"co ...

# %%
#Tienda2
df2 = pd.DataFrame(tienda2, columns = ['Categoría del Producto', 'Calificación'])

print(df2)


Categoría_promedio2 = df2.groupby('Categoría del Producto')['Calificación'].mean()
print("------------Calificación Promedio Tienda 2--------------------------------------------")
print(Categoría_promedio2)
Categoría_Reseteada_df2 = Categoría_promedio2.reset_index()
Categoría_Promedio2 = Categoría_Reseteada_df2.rename(columns={'Calificación': 'Calificación Promedio'})
print("------------Calificación Promedio Tienda 2 RESETEADA--------------------------------------------")
print(Categoría_Reseteada_df2)
print("------------Calificación Promedio Tienda 2 COLUMNA RENOMBRADA--------------------------------------------")
print(Categoría_Promedio2)
print("----------------Categorías Populares de la Tienda 2------------------")
Categorías_populares2 = Categoría_Promedio2[Categoría_Promedio2['Calificación Promedio'] > 4.03]
print(Categorías_populares2)
print("---------------Promedio de Calificación de los Clientes de la Tienda 2-----------------------------------------")
promedio_general2 = Categoría_Promedio2['Calificación Promedio'].mean()
print(f'El promedio de calificación de los clientes de la Tienda 2 considerando todas las categorías es: {promedio_general2:.2f}')

fig = px.pie(
    Categorías_populares2,
    values='Calificación Promedio',
    names='Categoría del Producto',
    title='Calificación Categorias Populares de la Tienda 2',
)

fig.update_traces(textposition='inside', textinfo='value')
fig.show()
# Out:
#        Categoría del Producto  Calificación
# 0                     Muebles             1
# 1      Instrumentos musicales             3
# 2                     Muebles             5
# 3                     Muebles             5
# 4                     Muebles             4
# ...                       ...           ...
# 2354  Artículos para el hogar             5
# 2355        Electrodomésticos             4
# 2356        Electrodomésticos             5
# 2357             Electrónicos             5
# 2358     Deportes y diversión             4
#
# [2359 rows x 2 columns]
# ------------Calificación Promedio Tienda 2--------------------------------------------
# Categoría del Producto
# Artículos para el hogar    4.071823
# Deportes y diversión       4.065455
# Electrodomésticos          4.072131
# Electrónicos               3.971564
# Instrumentos musicales     4.035714
# Juguetes                   4.025559
# Libros                     3.949239
# Muebles                    4.092760
# Name: Calificación, dtype: float64
# ------------Calificación Promedio Tienda 2 RESETEADA--------------------------------------------
#     Categoría del Producto  Calificación
# 0  Artículos para el hogar      4.071823
# 1     Deportes y diversión      4.065455
# 2        Electrodomésticos      4.072131
# 3             Electrónicos      3.971564
# 4   Instrumentos musicales      4.035714
# 5                 Juguetes      4.025559
# 6                   Libros      3.949239
# 7                  Muebles      4.092760
# ------------Calificación Promedio Tienda 2 COLUMNA RENOMBRADA--------------------------------------------
#     Categoría del Producto  Calificación Promedio
# 0  Artículos para el hogar               4.071823
# 1     Deportes y diversión               4.065455
# 2        Electrodomésticos               4.072131
# 3             Electrónicos               3.971564
# 4   Instrumentos musicales               4.035714
# 5                 Juguetes               4.025559
# 6                   Libros               3.949239
# 7                  Muebles               4.092760
# ----------------Categorías Populares de la Tienda 2------------------
#     Categoría del Producto  Calificación Promedio
# 0  Artículos para el hogar               4.071823
# 1     Deportes y diversión               4.065455
# 2        Electrodomésticos               4.072131
# 4   Instrumentos musicales               4.035714
# 7                  Muebles               4.092760
# ---------------Promedio de Calificación de los Clientes de la Tienda 2-----------------------------------------
# El promedio de calificación de los clientes de la Tienda 2 considerando todas las categorías es: 4.04
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7383aa23-2bc6-4b7c-84ed-2545f0cdb600" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7383aa23-2bc6-4b7c-84ed-2545f0cdb600")) {                    Plotly.newPlot(                        "7383aa23-2bc6-4b7c-84ed-2545f0cdb600",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Categoría del Producto=%{label}\u003cbr\u003eCalificación Promedio=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Artículos para el hogar","Deportes y diversión","Electrodomésticos","Instrumentos musicales","Muebles"],"legendgroup":"","name":"","showlegend":true,"values":[4.071823204419889,4.065454545454545,4.072131147540984,4.035714285714286,4.092760180995475],"type":"pie","textinfo":"value","textposition":"inside"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size" ...

# %%
print("-------------TIENDA 3-------------------------")

df3 = pd.DataFrame(tienda3, columns = ['Categoría del Producto', 'Calificación'])
print("--------------Se Crea DataFrame de la Tienda 3------------------------------------------")
print(df3)

Categoría_promedio3 = df3.groupby('Categoría del Producto')['Calificación'].mean()
print("------------Calificación Promedio Tienda 3--------------------------------------------")
print(Categoría_promedio3)
Categoría_Reseteada_df3 = Categoría_promedio3.reset_index()
Categoría_Promedio3 = Categoría_Reseteada_df3.rename(columns={'Calificación': 'Calificación Promedio'})
print("------------Calificación Promedio Tienda 3 RESETEADA--------------------------------------------")
print(Categoría_Reseteada_df3)
print("------------Calificación Promedio Tienda 3 COLUMNA RENOMBRADA--------------------------------------------")
print(Categoría_Promedio3)
print("----------------Categorías Populares de la Tienda 3------------------")
Categorías_populares3 = Categoría_Promedio3[Categoría_Promedio3['Calificación Promedio'] > 4.03]
print(Categorías_populares3)
print("---------------Promedio de Calificación de los Clientes de la Tienda 3-----------------------------------------")
promedio_general3 = Categoría_Promedio3['Calificación Promedio'].mean()
print(f'El promedio de calificación de los clientes de la Tienda 3 considerando todas las categorías es: {promedio_general3:.2f}')

fig = px.pie(
    Categorías_populares3,
    values='Calificación Promedio',
    names='Categoría del Producto',
    title='Calificación Categorias Populares de la Tienda 3',
)

fig.update_traces(textposition='inside', textinfo='value')
fig.show()
# Out:
# -------------TIENDA 3-------------------------
# --------------Se Crea DataFrame de la Tienda 3------------------------------------------
#       Categoría del Producto  Calificación
# 0          Electrodomésticos             4
# 1                    Muebles             3
# 2     Instrumentos musicales             5
# 3       Deportes y diversión             4
# 4                    Muebles             1
# ...                      ...           ...
# 2354                  Libros             5
# 2355                  Libros             5
# 2356                 Muebles             5
# 2357                 Muebles             4
# 2358                  Libros             5
#
# [2359 rows x 2 columns]
# ------------Calificación Promedio Tienda 3--------------------------------------------
# Categoría del Producto
# Artículos para el hogar    4.073446
# Deportes y diversión       3.938628
# Electrodomésticos          4.010791
# Electrónicos               3.986696
# Instrumentos musicales     4.005650
# Juguetes                   4.196825
# Libros                     4.048649
# Muebles                    4.098196
# Name: Calificación, dtype: float64
# ------------Calificación Promedio Tienda 3 RESETEADA--------------------------------------------
#     Categoría del Producto  Calificación
# 0  Artículos para el hogar      4.073446
# 1     Deportes y diversión      3.938628
# 2        Electrodomésticos      4.010791
# 3             Electrónicos      3.986696
# 4   Instrumentos musicales      4.005650
# 5                 Juguetes      4.196825
# 6                   Libros      4.048649
# 7                  Muebles      4.098196
# ------------Calificación Promedio Tienda 3 COLUMNA RENOMBRADA--------------------------------------------
#     Categoría del Producto  Calificación Promedio
# 0  Artículos para el hogar               4.073446
# 1     Deportes y diversión               3.938628
# 2        Electrodomésticos               4.010791
# 3             Electrónicos               3.986696
# 4   Instrumentos musicales               4.005650
# 5                 Juguetes               4.196825
# 6                   Libros               4.048649
# 7                  Muebles               4.098196
# ----------------Categorías Populares de la Tienda 3------------------
#     Categoría del Producto  Calificación Promedio
# 0  Artículos para el hogar               4.073446
# 5                 Juguetes               4.196825
# 6                   Libros               4.048649
# 7                  Muebles               4.098196
# ---------------Promedio de Calificación de los Clientes de la Tienda 3-----------------------------------------
# El promedio de calificación de los clientes de la Tienda 3 considerando todas las categorías es: 4.04
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="939ee5aa-d375-4ab4-8ea2-70b5c920c3ab" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("939ee5aa-d375-4ab4-8ea2-70b5c920c3ab")) {                    Plotly.newPlot(                        "939ee5aa-d375-4ab4-8ea2-70b5c920c3ab",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Categoría del Producto=%{label}\u003cbr\u003eCalificación Promedio=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Artículos para el hogar","Juguetes","Libros","Muebles"],"legendgroup":"","name":"","showlegend":true,"values":[4.073446327683616,4.196825396825397,4.048648648648649,4.098196392785571],"type":"pie","textinfo":"value","textposition":"inside"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scatter ...

# %%
print("-------------TIENDA 4-------------------------")

df4 = pd.DataFrame(tienda4, columns = ['Categoría del Producto', 'Calificación'])
print("--------------Se Crea DataFrame de la Tienda 4------------------------------------------")
print(df4)

Categoría_promedio4 = df4.groupby('Categoría del Producto')['Calificación'].mean()
print("------------Calificación Promedio Tienda 4--------------------------------------------")
print(Categoría_promedio4)
Categoría_Reseteada_df4 = Categoría_promedio4.reset_index()
Categoría_Promedio4 = Categoría_Reseteada_df4.rename(columns={'Calificación': 'Calificación Promedio'})
print("------------Calificación Promedio Tienda 4 RESETEADA--------------------------------------------")
print(Categoría_Reseteada_df4)
print("------------Calificación Promedio Tienda 4 COLUMNA RENOMBRADA--------------------------------------------")
print(Categoría_Promedio4)
print("----------------Categorías Populares de la Tienda 4------------------")
Categorías_populares4 = Categoría_Promedio4[Categoría_Promedio4['Calificación Promedio'] > 4.03]
print(Categorías_populares4)
print("---------------Promedio de Calificación de los Clientes de la Tienda 4-----------------------------------------")
promedio_general4 = Categoría_Promedio4['Calificación Promedio'].mean()
print(f'El promedio de calificación de los clientes de la Tienda 4 considerando todas las categorías es: {promedio_general4:.2f}')

fig = px.pie(
    Categorías_populares4,
    values='Calificación Promedio',
    names='Categoría del Producto',
    title='Calificación Categorias Populares de la Tienda 4',
)

fig.update_traces(textposition='inside', textinfo='value')
fig.show()
# Out:
# -------------TIENDA 4-------------------------
# --------------Se Crea DataFrame de la Tienda 4------------------------------------------
#        Categoría del Producto  Calificación
# 0           Electrodomésticos             4
# 1                     Muebles             5
# 2        Deportes y diversión             5
# 3                      Libros             3
# 4                Electrónicos             4
# ...                       ...           ...
# 2353                  Muebles             5
# 2354                  Muebles             5
# 2355     Deportes y diversión             5
# 2356  Artículos para el hogar             5
# 2357     Deportes y diversión             5
#
# [2358 rows x 2 columns]
# ------------Calificación Promedio Tienda 4--------------------------------------------
# Categoría del Producto
# Artículos para el hogar    4.009950
# Deportes y diversión       4.054152
# Electrodomésticos          3.929134
# Electrónicos               4.006652
# Instrumentos musicales     3.911765
# Juguetes                   3.988166
# Libros                     4.042781
# Muebles                    3.997917
# Name: Calificación, dtype: float64
# ------------Calificación Promedio Tienda 4 RESETEADA--------------------------------------------
#     Categoría del Producto  Calificación
# 0  Artículos para el hogar      4.009950
# 1     Deportes y diversión      4.054152
# 2        Electrodomésticos      3.929134
# 3             Electrónicos      4.006652
# 4   Instrumentos musicales      3.911765
# 5                 Juguetes      3.988166
# 6                   Libros      4.042781
# 7                  Muebles      3.997917
# ------------Calificación Promedio Tienda 4 COLUMNA RENOMBRADA--------------------------------------------
#     Categoría del Producto  Calificación Promedio
# 0  Artículos para el hogar               4.009950
# 1     Deportes y diversión               4.054152
# 2        Electrodomésticos               3.929134
# 3             Electrónicos               4.006652
# 4   Instrumentos musicales               3.911765
# 5                 Juguetes               3.988166
# 6                   Libros               4.042781
# 7                  Muebles               3.997917
# ----------------Categorías Populares de la Tienda 4------------------
#   Categoría del Producto  Calificación Promedio
# 1   Deportes y diversión               4.054152
# 6                 Libros               4.042781
# ---------------Promedio de Calificación de los Clientes de la Tienda 4-----------------------------------------
# El promedio de calificación de los clientes de la Tienda 4 considerando todas las categorías es: 3.99
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ff2fbb9b-f8cc-4893-ac3c-84a4872df22e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ff2fbb9b-f8cc-4893-ac3c-84a4872df22e")) {                    Plotly.newPlot(                        "ff2fbb9b-f8cc-4893-ac3c-84a4872df22e",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Categoría del Producto=%{label}\u003cbr\u003eCalificación Promedio=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Deportes y diversión","Libros"],"legendgroup":"","name":"","showlegend":true,"values":[4.054151624548736,4.042780748663102],"type":"pie","textinfo":"value","textposition":"inside"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}]," ...

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
#Obteniendo la cantidad de Productos Vendidos totales de la Tienda
import matplotlib.pyplot as plt
import pandas as pd


print("-----------------TOTAL TIENDA-----------------")

ventas_por_producto = df_tienda_total['Producto'].value_counts()
# Obtener el valor máximo y mínimo de ventas
max_ventas = ventas_por_producto.max()
min_ventas = ventas_por_producto.min()

# Filtrar todos los productos con el máximo de ventas
productos_mas_vendidos = ventas_por_producto[ventas_por_producto == max_ventas]
print(f'Productos más vendidos ({max_ventas} unidades):')
print(productos_mas_vendidos.to_string(index=True, header=False))

# Filtrar todos los productos con el mínimo de ventas
productos_menos_vendidos = ventas_por_producto[ventas_por_producto == min_ventas]
print(f'\nProductos menos vendidos ({min_ventas} unidades):')
print(productos_menos_vendidos.to_string(index=True, header=False))
# Out:
# -----------------TOTAL TIENDA-----------------
# Productos más vendidos (210 unidades):
# Mesa de noche    210
#
# Productos menos vendidos (157 unidades):
# Celular ABXY    157

# %%
import pandas as pd
import plotly.express as px

# Convirtiendo las series a DF
df_mas_vendidos = productos_mas_vendidos.reset_index()
df_mas_vendidos.columns = ['Producto', 'Cantidad Vendida']
df_mas_vendidos['Tipo'] = 'Más Vendido'

df_menos_vendidos = productos_menos_vendidos.reset_index()
df_menos_vendidos.columns = ['Producto', 'Cantidad Vendida']
df_menos_vendidos['Tipo'] = 'Menos Vendido'

# Concatenando los DF
df_ventas_combinadas = pd.concat([df_mas_vendidos, df_menos_vendidos])

# Creando el gráfico con Plotly Express
fig = px.bar(
    df_ventas_combinadas,
    x='Producto',
    y='Cantidad Vendida',
    color='Tipo',
    barmode='group',
    labels={'Producto': 'Producto', 'Cantidad Vendida': 'Cantidad Vendida', 'Tipo': 'Categoría'},
    title='Tienda Total: Los Producto Más y Menos Vendidos',
)

fig.update_layout(xaxis={'categoryorder':'total descending'})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c940363d-98ff-4459-85e4-1debea86ff01" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c940363d-98ff-4459-85e4-1debea86ff01")) {                    Plotly.newPlot(                        "c940363d-98ff-4459-85e4-1debea86ff01",                        [{"alignmentgroup":"True","hovertemplate":"Categoría=Más Vendido\u003cbr\u003eProducto=%{x}\u003cbr\u003eCantidad Vendida=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Más Vendido","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Más Vendido","offsetgroup":"Más Vendido","orientation":"v","showlegend":true,"textposition":"auto","x":["Mesa de noche"],"xaxis":"x","y":[210],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Categoría=Menos Vendido\u003cbr\u003eProducto=%{x}\u003cbr\u003eCantidad Vendida=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Menos Vendido","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Menos Vendido","offsetgroup":"Menos Vendido","orientation":"v","showlegend":true,"textposition":"auto","x":["Celular ABXY"],"xaxis":"x","y":[157],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity ...

# %%
print("------------------TIENDA 1--------------------")
#Tienda 1

ventas_por_producto1 = tienda['Producto'].value_counts()
max_ventas1 = ventas_por_producto1.max()
min_ventas1 = ventas_por_producto1.min()

# Filtrar todos los productos con el máximo de ventas
productos_mas_vendidos1 = ventas_por_producto1[ventas_por_producto1 == max_ventas1]
print(f'Productos más vendidos ({max_ventas1} unidades):')
print(productos_mas_vendidos1.to_string(index=True, header=False))

# Filtrar todos los productos con el mínimo de ventas
productos_menos_vendidos1 = ventas_por_producto1[ventas_por_producto1 == min_ventas1]
print(f'\nProductos menos vendidos ({min_ventas1} unidades):')
print(productos_menos_vendidos1.to_string(index=True, header=False))
# Out:
# ------------------TIENDA 1--------------------
# Productos más vendidos (60 unidades):
# Microondas       60
# TV LED UHD 4K    60
# Armario          60
#
# Productos menos vendidos (33 unidades):
# Auriculares con micrófono    33
# Celular ABXY                 33

# %%
import pandas as pd
import plotly.express as px

# Convirtiendo las series a DF
df_mas_vendidos1 = productos_mas_vendidos1.reset_index()
df_mas_vendidos1.columns = ['Producto', 'Cantidad Vendida']
df_mas_vendidos1['Tipo'] = 'Más Vendido'

df_menos_vendidos1 = productos_menos_vendidos1.reset_index()
df_menos_vendidos1.columns = ['Producto', 'Cantidad Vendida']
df_menos_vendidos1['Tipo'] = 'Menos Vendido'

# Concatenando los DF
df_ventas_combinadas1 = pd.concat([df_mas_vendidos1, df_menos_vendidos1])

# Creando el gráfico con Plotly Express
fig = px.bar(
    df_ventas_combinadas1,
    x='Producto',
    y='Cantidad Vendida',
    color='Tipo',
    barmode='group',
    labels={'Producto': 'Producto', 'Cantidad Vendida': 'Cantidad Vendida', 'Tipo': 'Categoría'},
    title='Tienda 1: Los Producto Más y Menos Vendidos',
)

fig.update_layout(xaxis={'categoryorder':'total descending'})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="081f9fa6-070d-4ea1-8281-afb512981323" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("081f9fa6-070d-4ea1-8281-afb512981323")) {                    Plotly.newPlot(                        "081f9fa6-070d-4ea1-8281-afb512981323",                        [{"alignmentgroup":"True","hovertemplate":"Categoría=Más Vendido\u003cbr\u003eProducto=%{x}\u003cbr\u003eCantidad Vendida=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Más Vendido","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Más Vendido","offsetgroup":"Más Vendido","orientation":"v","showlegend":true,"textposition":"auto","x":["Microondas","TV LED UHD 4K","Armario"],"xaxis":"x","y":[60,60,60],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Categoría=Menos Vendido\u003cbr\u003eProducto=%{x}\u003cbr\u003eCantidad Vendida=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Menos Vendido","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Menos Vendido","offsetgroup":"Menos Vendido","orientation":"v","showlegend":true,"textposition":"auto","x":["Auriculares con micrófono","Celular ABXY"],"xaxis":"x","y":[33,33],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter" ...

# %%
print("------------------TIENDA 2--------------------")
#Tienda 2

ventas_por_producto2 = tienda2['Producto'].value_counts()
max_ventas2 = ventas_por_producto2.max()
min_ventas2 = ventas_por_producto2.min()

# Filtrar todos los productos con el máximo de ventas
productos_mas_vendidos2 = ventas_por_producto2[ventas_por_producto2 == max_ventas2]
print(f'Productos más vendidos ({max_ventas2} unidades):')
print(productos_mas_vendidos2.to_string(index=True, header=False))

# Filtrar todos los productos con el mínimo de ventas
productos_menos_vendidos2 = ventas_por_producto2[ventas_por_producto2 == min_ventas2]
print(f'\nProductos menos vendidos ({min_ventas2} unidades):')
print(productos_menos_vendidos2.to_string(index=True, header=False))
# Out:
# ------------------TIENDA 2--------------------
# Productos más vendidos (65 unidades):
# Iniciando en programación    65
#
# Productos menos vendidos (32 unidades):
# Juego de mesa    32

# %%
import pandas as pd
import plotly.express as px

# Convirtiendo las series a DF
df_mas_vendidos2 = productos_mas_vendidos2.reset_index()
df_mas_vendidos2.columns = ['Producto', 'Cantidad Vendida']
df_mas_vendidos2['Tipo'] = 'Más Vendido'

df_menos_vendidos2 = productos_menos_vendidos2.reset_index()
df_menos_vendidos2.columns = ['Producto', 'Cantidad Vendida']
df_menos_vendidos2['Tipo'] = 'Menos Vendido'

# Concatenando los DF
df_ventas_combinadas2 = pd.concat([df_mas_vendidos2, df_menos_vendidos2])

# Creando el gráfico con Plotly Express
fig = px.bar(
    df_ventas_combinadas2,
    x='Producto',
    y='Cantidad Vendida',
    color='Tipo',
    barmode='group',
    labels={'Producto': 'Producto', 'Cantidad Vendida': 'Cantidad Vendida', 'Tipo': 'Categoría'},
    title='Tienda 2: Los Producto Más y Menos Vendidos',
)

fig.update_layout(xaxis={'categoryorder':'total descending'})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="15dcad86-b644-4e40-86e7-87f0100224f1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("15dcad86-b644-4e40-86e7-87f0100224f1")) {                    Plotly.newPlot(                        "15dcad86-b644-4e40-86e7-87f0100224f1",                        [{"alignmentgroup":"True","hovertemplate":"Categoría=Más Vendido\u003cbr\u003eProducto=%{x}\u003cbr\u003eCantidad Vendida=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Más Vendido","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Más Vendido","offsetgroup":"Más Vendido","orientation":"v","showlegend":true,"textposition":"auto","x":["Iniciando en programación"],"xaxis":"x","y":[65],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Categoría=Menos Vendido\u003cbr\u003eProducto=%{x}\u003cbr\u003eCantidad Vendida=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Menos Vendido","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Menos Vendido","offsetgroup":"Menos Vendido","orientation":"v","showlegend":true,"textposition":"auto","x":["Juego de mesa"],"xaxis":"x","y":[32],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":1 ...

# %%
print("------------------TIENDA 3--------------------")
#Tienda 3

ventas_por_producto3 = tienda3['Producto'].value_counts()
max_ventas3 = ventas_por_producto3.max()
min_ventas3 = ventas_por_producto3.min()

# Filtrar todos los productos con el máximo de ventas
productos_mas_vendidos3 = ventas_por_producto3[ventas_por_producto3 == max_ventas3]
print(f'Productos más vendidos ({max_ventas3} unidades):')
print(productos_mas_vendidos3.to_string(index=True, header=False))

# Filtrar todos los productos con el mínimo de ventas
productos_menos_vendidos3 = ventas_por_producto3[ventas_por_producto3 == min_ventas3]
print(f'\nProductos menos vendidos ({min_ventas3} unidades):')
print(productos_menos_vendidos3.to_string(index=True, header=False))
# Out:
# ------------------TIENDA 3--------------------
# Productos más vendidos (57 unidades):
# Kit de bancas    57
#
# Productos menos vendidos (35 unidades):
# Bloques de construcción    35

# %%
import pandas as pd
import plotly.express as px

# Convirtiendo las series a DF
df_mas_vendidos3 = productos_mas_vendidos3.reset_index()
df_mas_vendidos3.columns = ['Producto', 'Cantidad Vendida']
df_mas_vendidos3['Tipo'] = 'Más Vendido'

df_menos_vendidos3 = productos_menos_vendidos3.reset_index()
df_menos_vendidos3.columns = ['Producto', 'Cantidad Vendida']
df_menos_vendidos3['Tipo'] = 'Menos Vendido'

# Concatenando los DF
df_ventas_combinadas3 = pd.concat([df_mas_vendidos3, df_menos_vendidos3])

# Creando el gráfico con Plotly Express
fig = px.bar(
    df_ventas_combinadas3,
    x='Producto',
    y='Cantidad Vendida',
    color='Tipo',
    barmode='group',
    labels={'Producto': 'Producto', 'Cantidad Vendida': 'Cantidad Vendida', 'Tipo': 'Categoría'},
    title='Tienda 3: Los Producto Más y Menos Vendidos',
)

fig.update_layout(xaxis={'categoryorder':'total descending'})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a40de276-b454-4f1b-87a4-e934b65835f9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a40de276-b454-4f1b-87a4-e934b65835f9")) {                    Plotly.newPlot(                        "a40de276-b454-4f1b-87a4-e934b65835f9",                        [{"alignmentgroup":"True","hovertemplate":"Categoría=Más Vendido\u003cbr\u003eProducto=%{x}\u003cbr\u003eCantidad Vendida=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Más Vendido","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Más Vendido","offsetgroup":"Más Vendido","orientation":"v","showlegend":true,"textposition":"auto","x":["Kit de bancas"],"xaxis":"x","y":[57],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Categoría=Menos Vendido\u003cbr\u003eProducto=%{x}\u003cbr\u003eCantidad Vendida=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Menos Vendido","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Menos Vendido","offsetgroup":"Menos Vendido","orientation":"v","showlegend":true,"textposition":"auto","x":["Bloques de construcción"],"xaxis":"x","y":[35],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10, ...

# %%
print("------------------TIENDA 4--------------------")
#Tienda 4

ventas_por_producto4 = tienda4['Producto'].value_counts()
max_ventas4 = ventas_por_producto4.max()
min_ventas4 = ventas_por_producto4.min()

# Filtrar todos los productos con el máximo de ventas
productos_mas_vendidos4 = ventas_por_producto4[ventas_por_producto4 == max_ventas4]
print(f'Productos más vendidos ({max_ventas4} unidades):')
print(productos_mas_vendidos4.to_string(index=True, header=False))

# Filtrar todos los productos con el mínimo de ventas
productos_menos_vendidos4 = ventas_por_producto4[ventas_por_producto4 == min_ventas4]
print(f'\nProductos menos vendidos ({min_ventas4} unidades):')
print(productos_menos_vendidos4.to_string(index=True, header=False))
# Out:
# ------------------TIENDA 4--------------------
# Productos más vendidos (62 unidades):
# Cama box    62
#
# Productos menos vendidos (33 unidades):
# Guitarra eléctrica    33

# %%
import pandas as pd
import plotly.express as px

# Convirtiendo las series a DF
df_mas_vendidos4 = productos_mas_vendidos4.reset_index()
df_mas_vendidos4.columns = ['Producto', 'Cantidad Vendida']
df_mas_vendidos4['Tipo'] = 'Más Vendido'

df_menos_vendidos4 = productos_menos_vendidos4.reset_index()
df_menos_vendidos4.columns = ['Producto', 'Cantidad Vendida']
df_menos_vendidos4['Tipo'] = 'Menos Vendido'

# Concatenando los DF
df_ventas_combinadas4 = pd.concat([df_mas_vendidos4, df_menos_vendidos4])

# Creando el gráfico con Plotly Express
fig = px.bar(
    df_ventas_combinadas4,
    x='Producto',
    y='Cantidad Vendida',
    color='Tipo',
    barmode='group',
    labels={'Producto': 'Producto', 'Cantidad Vendida': 'Cantidad Vendida', 'Tipo': 'Categoría'},
    title='Tienda 4: Los Producto Más y Menos Vendidos',
)

fig.update_layout(xaxis={'categoryorder':'total descending'})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c26c5b3c-a33d-4d55-a4b2-faff33c477fe" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c26c5b3c-a33d-4d55-a4b2-faff33c477fe")) {                    Plotly.newPlot(                        "c26c5b3c-a33d-4d55-a4b2-faff33c477fe",                        [{"alignmentgroup":"True","hovertemplate":"Categoría=Más Vendido\u003cbr\u003eProducto=%{x}\u003cbr\u003eCantidad Vendida=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Más Vendido","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Más Vendido","offsetgroup":"Más Vendido","orientation":"v","showlegend":true,"textposition":"auto","x":["Cama box"],"xaxis":"x","y":[62],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Categoría=Menos Vendido\u003cbr\u003eProducto=%{x}\u003cbr\u003eCantidad Vendida=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Menos Vendido","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Menos Vendido","offsetgroup":"Menos Vendido","orientation":"v","showlegend":true,"textposition":"auto","x":["Guitarra eléctrica"],"xaxis":"x","y":[33],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity" ...

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
print("----Costo Promedio del Envío---------------")
# Out:
# ----Costo Promedio del Envío---------------

# %%
print("--------------Tienda Total : Costo Promedio del Envío------------")
Costo_Promedio_Envio = df_tienda_total['Costo de envío'].mean()
print(Costo_Promedio_Envio)
print("--------------Tienda 1 : Costo Promedio del Envío------------")
Costo_Promedio_Envio1 = tienda['Costo de envío'].mean()
print(Costo_Promedio_Envio1)
print("--------------Tienda 2 : Costo Promedio del Envío------------")
Costo_Promedio_Envio2 = tienda2['Costo de envío'].mean()
print(Costo_Promedio_Envio2)
print("--------------Tienda 3 : Costo Promedio del Envío------------")
Costo_Promedio_Envio3 = tienda3['Costo de envío'].mean()
print(Costo_Promedio_Envio3)
print("--------------Tienda 4 : Costo Promedio del Envío------------")
Costo_Promedio_Envio4 = tienda4['Costo de envío'].mean()
print(Costo_Promedio_Envio4)
# Out:
# --------------Tienda Total : Costo Promedio del Envío------------
# 24875.145733969264
# --------------Tienda 1 : Costo Promedio del Envío------------
# 26018.60958033065
# --------------Tienda 2 : Costo Promedio del Envío------------
# 25216.235693090293
# --------------Tienda 3 : Costo Promedio del Envío------------
# 24805.680373039424
# --------------Tienda 4 : Costo Promedio del Envío------------
# 23459.457167090754

# %%
# Calculando el promedio del costo para cada tienda y el promedio total
Promedio_costo_envio = {
    'Tienda': ['Total Tienda', 'Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4'],
    'Costo Promedio Envio': [
        df_tienda_total['Costo de envío'].mean(),
        tienda['Costo de envío'].mean(),
        tienda2['Costo de envío'].mean(),
        tienda3['Costo de envío'].mean(),
        tienda4['Costo de envío'].mean()
    ]
}

df_promedio_envio = pd.DataFrame(Promedio_costo_envio)
display(df_promedio_envio)
# Out:
#          Tienda  Costo Promedio Envio
# 0  Total Tienda          24875.145734
# 1      Tienda 1          26018.609580
# 2      Tienda 2          25216.235693
# 3      Tienda 3          24805.680373
# 4      Tienda 4          23459.457167

# %% [markdown]
# **Reasoning**:
# Generate a pie chart using Plotly Express to visualize the percentage contribution of each store to the total revenue.

# %%
# Gráfico de Línea con el promedio de costos de envío
plt.figure(figsize=(8, 5))
sns.lineplot(x='Tienda', y='Costo Promedio Envio', data=df_promedio_envio, marker='o')
plt.xlabel('Tienda')
plt.ylabel('Costo Promedio Envio')
plt.title('Costo Promedio Envio por Tienda')

# Aplicando formato de divisa
formatter = mtick.StrMethodFormatter('${x:,.0f}')
plt.gca().yaxis.set_major_formatter(formatter)

plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Bar plot of average shipping cost per store
plt.figure(figsize=(8, 5))
sns.barplot(x='Tienda', y='Costo Promedio Envio', data=df_promedio_envio)
plt.xlabel('Tienda')
plt.ylabel('Costo Promedio Envio')
plt.title('Costo Promedio Envio por Tienda')

# Aplicando formato de divisa
formatter = mtick.StrMethodFormatter('${x:,.0f}')
plt.gca().yaxis.set_major_formatter(formatter)

plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
# Separando el promedio total de la tienda con las tiendas individuales
# se crea un tipo de diagrama de dispersión

df_promedio_total = df_promedio_envio[df_promedio_envio['Tienda'] == 'Total Tienda']
df_promedio_individual = df_promedio_envio[df_promedio_envio['Tienda'] != 'Total Tienda']

plt.figure(figsize=(8, 5))

# Puntos de datos de cada tienda
sns.scatterplot(x='Tienda', y='Costo Promedio Envio', data=df_promedio_individual, s=100, label='Costo Promedio por Tienda')

# línea horiozntal del costo promedio total de la tienda
plt.axhline(y=df_promedio_total['Costo Promedio Envio'].iloc[0], color='yellow', linestyle='--', label='Costo Promedio Total')

plt.xlabel('Tienda')
plt.ylabel('Costo Promedio Envio')
plt.title('Costo Promedio Envio por Tienda vs Costo Promedio Total')

# Aplicando formato de divisa
formatter = mtick.StrMethodFormatter('${x:,.0f}')
plt.gca().yaxis.set_major_formatter(formatter)

plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend()
plt.show()

# %% [markdown]
# # CONCLUSION
#
# Sr Juan:
#
# Se recomienda vender la Tienda 4 ya que esta generalmente tiene ventas más bajas que las demás, especialmente en "Electródomesticos" e "Instrumentos Musicales", además la tienda 4 tiene menor Ingreso Total que el resto de las 3 tiendas.
#
# Respecto a los productos más y menos vendidos de la tienda 4, el producto más vendido ("Cama Box") tiene un buen desempeño respecto a otras tiendas, lo que favorece esa línea de negocio para la tienda 4. Por el contrario, su producto menos vendido ("Guitarra Electrica") podría índicar una debilidad de esa categoría en comparación con las otras tiendas.
#
# Todas las tiendas tienen una calificación promedio relativamente similar, la tienda 4 con una califación levemente bajo el promedio de calificacion de la tienda total, que si bien es una diferencia  marginal, complementa la decisión de vender. Por otro lado, la tienda 4 es la que tiene el costo más bajo de envío, lo cual es destacable pero no es relevante para el analísis que se está realizando, no influye en nuestra decisión de vender esta tienda por más que tenga el costo más bajo de todas, finalmente es marginal la diferencia respecto al promedio del costo total de envío.
#
# La tienda 4 es el candidato más fuerte para la desinversión contemplando el objetivo principal que es eliminar una tienda, para financiar una nueva empresa.
